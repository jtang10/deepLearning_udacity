# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _  = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)

    data = list()
    unk_count = 0

    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0 # dictionary['UNK']
            unk_count += 1
        data.append(index)

    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words # Hint to reduce memory
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # Number of words to consider left and right.
num_skips = 2 # How many times to resue an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                             stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, 
                                   inputs=embed, labels=train_labels, 
                                   num_sampled=num_sampled, num_classes=vocabulary_size))
    # Optimizer
    # Optimizer will optimize both the softmax_weights AND the embeddings.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # Use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.513545
# Nearest to in: audi, superfund, compulsory, siding, antihydrogen, minimal, ganymede, desiring,
# Nearest to he: frodo, cordwainer, suction, reverted, librivox, swaziland, topalov, knowledge,
# Nearest to more: fireside, zaghawa, pictures, organism, dixieland, hermeneutic, franks, meissen,
# Nearest to state: screech, aorist, acetylcholine, omphale, weyl, obey, ravaging, historic,
# Nearest to into: elba, torment, lim, tdi, coolant, argentinian, clairvoyance, crocodile,
# Nearest to many: plummer, sst, infusions, hurrian, mamma, headlined, blows, phenomenon,
# Nearest to also: diomedea, copps, painless, trophic, apollonia, kant, diderot, games,
# Nearest to it: rearing, honesty, greyface, africana, abolish, lid, initiatives, obi,
# Nearest to only: peng, hayden, geisel, senators, ry, pod, kirtland, caspase,
# Nearest to between: vestalia, landmark, smokey, starship, microscope, bund, sopra, atl,
# Nearest to or: labeling, care, guelfs, stuffing, possessions, hadassah, amulets, cgi,
# Nearest to that: turgot, orgasm, dusseldorf, highlands, selfish, futility, precursor, uplift,
# Nearest to been: awakens, denison, synonymously, literate, fictional, dent, bosman, relegation,
# Nearest to there: richelieu, meyers, priming, sightseeing, subregion, trios, keillor, sive,
# Nearest to they: visuals, saudi, shuts, independant, irene, berbers, hamlet, scaled,
# Nearest to american: cn, expected, sos, businesspeople, silent, merge, ller, rows,
# Average loss at step 2000: 4.350880
# Average loss at step 4000: 3.922925
# Average loss at step 6000: 3.829660
# Average loss at step 8000: 3.665570
# Average loss at step 10000: 3.614415
# Nearest to in: during, at, on, is, with, of, refrigerated, from,
# Nearest to he: it, she, they, lhasa, egypt, faire, there, andamanese,
# Nearest to more: zaghawa, organism, utilitarianism, chondrite, hou, winters, fireside, inflected,
# Nearest to state: aorist, weyl, adequately, nous, omphale, screech, foci, mozambique,
# Nearest to into: to, coolant, on, elba, with, ischemia, devas, from,
# Nearest to many: some, avestan, these, manometer, plummer, any, janitor, anchors,
# Nearest to also: which, militant, generally, above, cumbric, anno, who, calais,
# Nearest to it: he, this, there, she, not, they, which, bureaucracy,
# Nearest to only: isomer, saddened, verbal, revulsion, caspase, hayden, tahiti, words,
# Nearest to between: from, bund, starship, interchange, demarco, on, pulmonary, by,
# Nearest to or: opencourseware, and, than, analogous, flanked, mistranslation, monitoring, harappan,
# Nearest to that: which, this, autoroute, alignment, consigned, oplus, shipowner, brackish,
# Nearest to been: synonymously, awakens, obligation, agate, was, be, by, decipherment,
# Nearest to there: it, they, not, this, epochs, outlawing, manned, he,
# Nearest to they: there, not, visuals, it, you, he, we, saudi,
# Nearest to american: ethical, cn, dispensation, turned, stockton, endosperm, grows, businesspeople,
# Average loss at step 12000: 3.635515
# Average loss at step 14000: 3.605841
# Average loss at step 16000: 3.587873
# Average loss at step 18000: 3.559908
# Average loss at step 20000: 3.539330
# Nearest to in: during, at, on, with, of, and, from, between,
# Nearest to he: she, it, they, there, who, faire, lhasa, but,
# Nearest to more: less, most, zaghawa, organism, winters, very, utilitarianism, chondrite,
# Nearest to state: adequately, weyl, aorist, fins, money, danubian, predated, truncated,
# Nearest to into: from, with, byzantine, around, repay, to, ischemia, on,
# Nearest to many: some, these, several, any, anchors, all, other, scale,
# Nearest to also: which, often, who, generally, seif, cumbric, already, erc,
# Nearest to it: he, she, there, this, itinerant, they, which, not,
# Nearest to only: tahiti, eaters, encodes, saddened, tyrol, projectile, leonardo, currently,
# Nearest to between: from, with, in, greenwood, around, pulmonary, demarco, interchange,
# Nearest to or: and, than, analogous, plucking, opencourseware, deficiency, frey, dewdney,
# Nearest to that: which, this, however, but, duryodhana, coretta, it, transubstantiation,
# Nearest to been: be, become, synonymously, by, was, decipherment, never, were,
# Nearest to there: they, it, he, now, these, no, which, epochs,
# Nearest to they: there, he, we, you, it, not, visuals, who,
# Nearest to american: english, dispensation, ethical, silent, british, domino, cn, grows,
# Average loss at step 22000: 3.455923
# Average loss at step 24000: 3.426836
# Average loss at step 26000: 3.494080
# Average loss at step 28000: 3.413819
# Average loss at step 30000: 3.424246
# Nearest to in: during, on, of, at, with, under, taunted, between,
# Nearest to he: she, it, they, who, there, lhasa, tua, originally,
# Nearest to more: less, most, very, zaghawa, winters, organism, chondrite, utilitarianism,
# Nearest to state: adequately, nous, money, fins, weyl, aorist, plymouth, predated,
# Nearest to into: with, under, from, byzantine, repay, between, around, within,
# Nearest to many: some, several, these, all, most, any, other, horace,
# Nearest to also: which, often, now, generally, erc, cumbric, who, unpopularity,
# Nearest to it: he, there, she, this, they, now, not, faire,
# Nearest to only: saddened, tahiti, just, until, pickle, not, cars, question,
# Nearest to between: from, with, spouses, pulmonary, into, greenwood, around, banaba,
# Nearest to or: and, than, invert, oscillating, jong, synthesized, adjudication, flanked,
# Nearest to that: which, where, alignment, however, oplus, duryodhana, what, consigned,
# Nearest to been: become, be, synonymously, never, was, by, decipherment, had,
# Nearest to there: they, it, he, now, believed, often, epochs, no,
# Nearest to they: he, there, we, you, it, these, who, she,
# Nearest to american: english, british, theron, dispensation, and, bonneville, german, italian,
# Average loss at step 32000: 3.443217
# Average loss at step 34000: 3.375308
# Average loss at step 36000: 3.501516
# Average loss at step 38000: 3.453802
# Average loss at step 40000: 3.434515
# Nearest to in: of, at, on, during, from, under, within, since,
# Nearest to he: she, it, they, who, there, later, tua, however,
# Nearest to more: less, most, very, ecclesia, winters, organism, penance, zaghawa,
# Nearest to state: plymouth, adequately, phraseology, arising, werke, weyl, predated, fins,
# Nearest to into: through, within, from, byzantine, under, around, between, aggressive,
# Nearest to many: some, several, these, all, any, other, most, various,
# Nearest to also: now, often, which, generally, sometimes, gradually, unpopularity, who,
# Nearest to it: he, there, she, this, itinerant, they, what, sometimes,
# Nearest to only: until, not, characterises, actually, answering, therefore, causing, first,
# Nearest to between: with, from, spouses, banaba, around, greenwood, eridu, pulmonary,
# Nearest to or: and, than, zuse, but, pharmacology, telephus, mauchly, denison,
# Nearest to that: which, however, this, where, what, alignment, credit, consigned,
# Nearest to been: become, be, was, were, synonymously, anni, never, estis,
# Nearest to there: it, they, now, he, we, believed, still, often,
# Nearest to they: we, there, you, he, she, it, who, i,
# Nearest to american: british, dispensation, irish, english, italian, european, german, domino,
# Average loss at step 42000: 3.281364
# Average loss at step 44000: 3.417845
# Average loss at step 46000: 3.435670
# Average loss at step 48000: 3.441579
# Average loss at step 50000: 3.463022
# Nearest to in: during, on, since, with, under, at, of, through,
# Nearest to he: she, it, they, who, there, i, bulb, originally,
# Nearest to more: less, most, very, zaghawa, ecclesia, too, crossbow, winters,
# Nearest to state: government, adequately, arising, abstractly, plymouth, parliament, money, racketeering,
# Nearest to into: from, through, within, around, byzantine, under, on, with,
# Nearest to many: some, several, these, various, other, all, most, both,
# Nearest to also: now, often, which, generally, sometimes, it, gradually, barrington,
# Nearest to it: he, she, there, this, they, itinerant, what, we,
# Nearest to only: generously, until, currently, algorithmic, overloaded, therefore, pros, written,
# Nearest to between: from, around, with, through, banaba, spouses, in, depravity,
# Nearest to or: and, than, waterproof, but, hainan, zuse, telephus, pharmacology,
# Nearest to that: which, however, this, what, duryodhana, where, consigned, but,
# Nearest to been: become, be, was, were, never, estis, had, decipherment,
# Nearest to there: they, it, he, still, now, we, which, often,
# Nearest to they: we, he, there, you, she, i, it, these,
# Nearest to american: british, english, italian, australian, german, dispensation, irish, french,
# Average loss at step 52000: 3.436067
# Average loss at step 54000: 3.410776
# Average loss at step 56000: 3.285050
# Average loss at step 58000: 3.385815
# Average loss at step 60000: 3.445164
# Nearest to in: during, within, on, at, since, from, by, with,
# Nearest to he: she, it, they, there, who, tomasz, coterminous, graf,
# Nearest to more: less, most, very, distraught, zaghawa, ecclesia, kew, chondrite,
# Nearest to state: government, abstractly, parliament, adequately, plymouth, branch, arising, disraeli,
# Nearest to into: through, from, within, byzantine, under, around, devas, sanctuaries,
# Nearest to many: some, several, these, various, all, most, both, certain,
# Nearest to also: now, often, never, generally, who, which, still, sometimes,
# Nearest to it: he, there, she, this, we, they, itinerant, which,
# Nearest to only: therefore, currently, not, until, actually, just, anatolia, algorithmic,
# Nearest to between: spouses, within, with, through, eridu, around, banaba, in,
# Nearest to or: and, than, zuse, s, pompeius, telephus, glaze, a,
# Nearest to that: which, this, however, what, alignment, phenotypes, consigned, often,
# Nearest to been: become, be, was, were, being, estis, synonymously, never,
# Nearest to there: they, it, still, he, believed, we, currently, often,
# Nearest to they: we, there, you, he, she, these, it, not,
# Nearest to american: british, italian, french, english, irish, german, australian, european,
# Average loss at step 62000: 3.366946
# Average loss at step 64000: 3.352322
# Average loss at step 66000: 3.388746
# Average loss at step 68000: 3.376640
# Average loss at step 70000: 3.411405
# Nearest to in: during, on, at, within, rydberg, throughout, chiapas, ibo,
# Nearest to he: she, they, it, there, who, later, i, tua,
# Nearest to more: less, most, very, distraught, balliol, extremely, ecclesia, better,
# Nearest to state: government, branch, parliament, abstractly, states, republic, plymouth, werke,
# Nearest to into: through, within, from, around, byzantine, under, during, devas,
# Nearest to many: some, several, these, all, various, both, numerous, such,
# Nearest to also: now, often, which, still, generally, never, sometimes, usually,
# Nearest to it: he, there, she, this, which, they, itinerant, bruges,
# Nearest to only: until, not, vc, no, actually, just, algorithmic, even,
# Nearest to between: with, around, spouses, over, within, banaba, through, eridu,
# Nearest to or: and, than, pinching, waterproof, denison, boarded, telephus, chickenpox,
# Nearest to that: which, however, what, this, alignment, consigned, gnostic, when,
# Nearest to been: become, be, were, being, grown, estis, was, since,
# Nearest to there: they, it, he, we, still, she, currently, believed,
# Nearest to they: we, he, there, you, she, i, it, who,
# Nearest to american: italian, french, british, english, german, irish, vt, african,
# Average loss at step 72000: 3.390414
# Average loss at step 74000: 3.357016
# Average loss at step 76000: 3.237840
# Average loss at step 78000: 3.381990
# Average loss at step 80000: 3.297301
# Nearest to in: during, within, on, throughout, at, around, under, from,
# Nearest to he: she, it, they, there, who, we, tua, fedayeen,
# Nearest to more: less, most, very, too, sortavala, highly, ecclesia, increasingly,
# Nearest to state: branch, government, parliament, cryptographer, satavahana, states, subway, adequately,
# Nearest to into: through, from, within, around, under, sims, towards, byzantine,
# Nearest to many: some, several, these, various, all, numerous, most, few,
# Nearest to also: now, often, which, still, generally, usually, sometimes, never,
# Nearest to it: he, she, there, this, they, itinerant, never, we,
# Nearest to only: until, no, either, disassembled, vc, even, characterises, first,
# Nearest to between: around, banaba, within, among, with, over, through, stalinist,
# Nearest to or: and, than, though, but, telephus, while, although, opencourseware,
# Nearest to that: which, what, but, however, this, where, culp, alignment,
# Nearest to been: become, be, grown, was, estis, being, recently, considerably,
# Nearest to there: they, it, he, still, she, we, believed, this,
# Nearest to they: we, you, there, he, she, it, who, these,
# Nearest to american: british, french, italian, irish, german, canadian, english, australian,
# Average loss at step 82000: 3.343319
# Average loss at step 84000: 3.350712
# Average loss at step 86000: 3.325310
# Average loss at step 88000: 3.243673
# Average loss at step 90000: 2.740002
# Nearest to in: at, during, near, from, with, around, until, on,
# Nearest to he: she, it, they, there, who, never, later, we,
# Nearest to more: less, most, very, ecclesia, rather, crossbow, smaller, balliol,
# Nearest to state: government, branch, states, parliament, satavahana, arising, adequately, cryptographer,
# Nearest to into: through, within, from, under, towards, around, byzantine, showtime,
# Nearest to many: some, several, all, various, these, numerous, those, few,
# Nearest to also: often, now, which, still, never, who, that, later,
# Nearest to it: he, she, there, this, they, we, itinerant, tua,
# Nearest to only: last, until, first, extensively, characterises, vc, oldest, boas,
# Nearest to between: around, with, among, through, from, banaba, within, eridu,
# Nearest to or: than, and, though, denison, libert, floorball, waterproof, but,
# Nearest to that: which, however, what, often, this, duryodhana, also, pekka,
# Nearest to been: become, be, grown, was, had, already, is, being,
# Nearest to there: they, it, we, she, still, he, believed, usually,
# Nearest to they: we, you, he, there, she, it, i, who,
# Nearest to american: english, british, german, french, italian, canadian, and, william,
# Average loss at step 92000: 3.107891
# Average loss at step 94000: 3.068460
# Average loss at step 96000: 3.224303
# Average loss at step 98000: 3.281026
# Average loss at step 100000: 3.282023
# Nearest to in: on, during, within, at, around, until, from, near,
# Nearest to he: she, it, they, there, but, tua, we, who,
# Nearest to more: less, most, very, better, rather, quite, too, ecclesia,
# Nearest to state: government, states, branch, parliament, congress, arising, satavahana, adequately,
# Nearest to into: through, within, from, under, around, towards, byzantine, down,
# Nearest to many: some, several, these, various, numerous, both, all, those,
# Nearest to also: often, now, still, which, never, usually, eventually, who,
# Nearest to it: he, she, there, this, tua, itinerant, now, itself,
# Nearest to only: last, either, until, characterises, not, ranching, extensively, first,
# Nearest to between: with, around, within, among, in, through, banaba, from,
# Nearest to or: and, than, any, but, preeminent, denison, waterproof, dsn,
# Nearest to that: which, however, what, when, alignment, this, catalyzed, because,
# Nearest to been: become, be, was, grown, were, being, since, recently,
# Nearest to there: it, they, still, believed, we, she, he, now,
# Nearest to they: we, she, you, he, there, i, these, hardwicke,
# Nearest to american: british, english, australian, canadian, french, irish, italian, german,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
